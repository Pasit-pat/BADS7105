# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ziriu\OneDrive\Documents\GitHub\BADS7105\Homework 1\Raw Data\RAW1.csv")

# %%
df.head()
# Out:
#            Timestamp คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารญี่ปุ่น]  \
# 0  1/9/2021 10:07:27                                               สนใจ
# 1  1/9/2021 10:07:34                                       สนใจอย่างมาก
# 2  1/9/2021 10:07:36                                 สนใจอย่างมากที่สุด
# 3  1/9/2021 10:07:36                                               สนใจ
# 4  1/9/2021 10:07:42                                       สนใจอย่างมาก
#
#   คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารจึน]  \
# 0                                               สนใจ
# 1                                               เฉยๆ
# 2                                               เฉยๆ
# 3                                               เฉยๆ
# 4                                               สนใจ
#
#   คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารไทย]  \
# 0                                 สนใจอย่างมากที่สุด
# 1                                 สนใจอย่างมากที่สุด
# ...

# %%
df.shape
# Out:
# (63, 66)

# %%
df['คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารญี่ปุ่น]'].value_counts()
# Out:
# สนใจอย่างมากที่สุด    25
# สนใจอย่างมาก          21
# สนใจ                  14
# เฉยๆ                   3
# Name: คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารญี่ปุ่น], dtype: int64

# %%
df['คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารจึน]'].value_counts(normalize=True)
# Out:
# สนใจ                     0.317460
# เฉยๆ                     0.301587
# สนใจอย่างมาก             0.190476
# ไม่สนใจ                  0.095238
# สนใจอย่างมากที่สุด       0.063492
# ไม่สนใจอย่างมากที่สุด    0.015873
# ไม่สนใจอย่างมาก          0.015873
# Name: คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารจึน], dtype: float64

# %%
# %matplotlib inline

# %%
df['ช่วยอายุ'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df['อายุ'].value_counts().plot(kind="bar", figsize=(15,7), color="#61d199")
# Out:
# <AxesSubplot:>

# %%
df['อายุ'].value_counts()
# Out:
# 27    10
# 29     9
# 28     7
# 26     5
# 24     4
# 35     4
# 32     4
# 31     3
# 33     3
# 30     3
# 25     2
# 22     1
# 47     1
# 44     1
# 34     1
# 36     1
# 40     1
# 42     1
# 43     1
# 0      1
# Name: อายุ, dtype: int64

# %%
said_no = df[df['คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [เหล้าเบียร์]'] == 'ไม่สนใจ']
said_no.head(3)
# Out:
#             Timestamp  \
# 1   1/9/2021 10:07:34
# 8   1/9/2021 10:08:08
# 11  1/9/2021 10:08:23
#
#    คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารญี่ปุ่น]  \
# 1                                        สนใจอย่างมาก
# 8                                  สนใจอย่างมากที่สุด
# 11                                               สนใจ
#
#    คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารจึน]  \
# 1                                                เฉยๆ
# 8                                             ไม่สนใจ
# 11                                               เฉยๆ
#
#    คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารไทย]  \
# 1                                  สนใจอย่างมากที่สุด
# 8                                        สนใจอย่างมาก
# 11                                       สนใจอย่างมาก
#
#    คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารอีสาน]  \
# 1                                        สนใจอย่างมาก
# 8                                        สนใจอย่างมาก
# ...

# %%
df['คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [เหล้าเบียร์]'].value_counts()
# Out:
# เฉยๆ                     13
# สนใจอย่างมากที่สุด       10
# ไม่สนใจ                  10
# ไม่สนใจอย่างมากที่สุด     9
# สนใจ                      8
# สนใจอย่างมาก              8
# ไม่สนใจอย่างมาก           5
# Name: คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [เหล้าเบียร์], dtype: int64

# %%
said_no.shape
# Out:
# (10, 66)

# %%
said_no['คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [เหล้าเบียร์]'].value_counts()
# Out:
# ไม่สนใจ    10
# Name: คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [เหล้าเบียร์], dtype: int64

# %%
said_yes = df[df['คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [เหล้าเบียร์]'] == 'สนใจอย่างมากที่สุด']
said_yes.head(3)
# Out:
#            Timestamp คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารญี่ปุ่น]  \
# 0  1/9/2021 10:07:27                                               สนใจ
# 5  1/9/2021 10:07:42                                 สนใจอย่างมากที่สุด
# 7  1/9/2021 10:08:05                                       สนใจอย่างมาก
#
#   คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารจึน]  \
# 0                                               สนใจ
# 5                                 สนใจอย่างมากที่สุด
# 7                                            ไม่สนใจ
#
#   คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารไทย]  \
# 0                                 สนใจอย่างมากที่สุด
# 5                                 สนใจอย่างมากที่สุด
# 7                                 สนใจอย่างมากที่สุด
#
#   คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารอีสาน]  \
# 0                                       สนใจอย่างมาก
# 5                                               สนใจ
# 7                                 สนใจอย่างมากที่สุด
#
# ...

# %%
print(said_no['อายุ'].mean(),
      said_yes['อายุ'].mean(),
      said_no['อายุ'].median(),
      said_yes['อายุ'].median()
     )

missingout = [said_no['อายุ'].mean(),
      said_yes['อายุ'].mean(),
      said_no['อายุ'].median(),
      said_yes['อายุ'].median()]
# Out:
# 28.7 29.0 27.5 29.0

# %%
from matplotlib import pyplot as plt
plt.plot(missingout)

plt.show()

# %%
over50 = df[df['อายุ'] <= 50]
under25 = df[df['อายุ'] > 25]

# %%
print(over50['คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [บุฟเฟต์]'].value_counts(normalize=True))
print(under25['คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [บุฟเฟต์]'].value_counts(normalize=True))
# Out:
# สนใจอย่างมากที่สุด    0.269841
# สนใจอย่างมาก          0.238095
# เฉยๆ                  0.222222
# สนใจ                  0.206349
# ไม่สนใจ               0.047619
# ไม่สนใจอย่างมาก       0.015873
# Name: คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [บุฟเฟต์], dtype: float64
# สนใจอย่างมาก          0.236364
# เฉยๆ                  0.236364
# สนใจ                  0.236364
# สนใจอย่างมากที่สุด    0.218182
# ไม่สนใจ               0.054545
# ไม่สนใจอย่างมาก       0.018182
# Name: คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [บุฟเฟต์], dtype: float64

# %%
print(len(over50))
print(len(under25))
# Out:
# 63
# 55

# %%
filtered_1 = df[(df['คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [เหล้าเบียร์]'] == 'สนใจอย่างมากที่สุด') & (df['ช่วยอายุ'] == '21-30')]

# %%
print(filtered_1['คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [เหล้าเบียร์]'].value_counts())
print(filtered_1['ช่วยอายุ'].value_counts())
# Out:
# สนใจอย่างมากที่สุด    7
# Name: คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [เหล้าเบียร์], dtype: int64
# 21-30    7
# Name: ช่วยอายุ, dtype: int64

# %%
df.head()
# Out:
#            Timestamp คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารญี่ปุ่น]  \
# 0  1/9/2021 10:07:27                                               สนใจ
# 1  1/9/2021 10:07:34                                       สนใจอย่างมาก
# 2  1/9/2021 10:07:36                                 สนใจอย่างมากที่สุด
# 3  1/9/2021 10:07:36                                               สนใจ
# 4  1/9/2021 10:07:42                                       สนใจอย่างมาก
#
#   คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารจึน]  \
# 0                                               สนใจ
# 1                                               เฉยๆ
# 2                                               เฉยๆ
# 3                                               เฉยๆ
# 4                                               สนใจ
#
#   คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารไทย]  \
# 0                                 สนใจอย่างมากที่สุด
# 1                                 สนใจอย่างมากที่สุด
# ...
